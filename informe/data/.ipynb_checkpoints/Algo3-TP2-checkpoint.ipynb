# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import random
import glob
import os

# %% [markdown]
# # Problema 1

# %%
df = pd.read_csv('delivery.csv')

# %%
dfA = df[(df.Ciudades > 0) & (df.Rutas == 5) & (df.TotalPremium == 3) & (df.LimitePremium == 2)]

sns.lmplot(x='Ciudades', y='Nanosegundos', data=dfA, truncate=True, size=7, aspect=1.4)
plt.show()

# %%
dfB = df[(df.Ciudades == 10) & (df.Rutas > 5) & (df.TotalPremium == 5) & (df.LimitePremium == 2)]

sns.lmplot(x='Rutas', y='Nanosegundos', data=dfB, truncate=True, size=7, aspect=1.4)
plt.show()

# %%
dfC = df[(df.Ciudades == 10) & (df.Rutas == 20) & (df.TotalPremium > 1) & (df.LimitePremium == 2)]

sns.lmplot(x='TotalPremium', y='Nanosegundos', data=dfC, truncate=True, size=7, aspect=1.4)
plt.show()

# %%
dfD = df[(df.Ciudades == 10) & (df.Rutas == 30) & (df.TotalPremium > 0) & (df.LimitePremium > 0)]

sns.lmplot(x='LimitePremium', y='Nanosegundos', data=dfD, truncate=True, size=7, aspect=1.4)
plt.show()
